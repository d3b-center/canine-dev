# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
consensusvcfcalls = pd.read_csv("results/all_samples_consensus_comparisons", header=None, sep="\t", 
                       names=["Padding", "Sample", "Num of var", "Var missing compared to 300-600"])

# %%
consensusvcfcalls
# Out:
#     Padding             Sample  Num of var  \
# 0   300-600  WHCGBM_0000000004        3578
# 1   200-400  WHCGBM_0000000004        3581
# 2   150-300  WHCGBM_0000000004        3564
# 3    75-150  WHCGBM_0000000004        3533
# 4   300-600  WHCGBM_0000000010        6506
# 5   200-400  WHCGBM_0000000010        6474
# 6   150-300  WHCGBM_0000000010        6428
# 7    75-150  WHCGBM_0000000010        6252
# 8   300-600  WHCGBM_0000000011        8682
# 9   200-400  WHCGBM_0000000011        8688
# 10  150-300  WHCGBM_0000000011        8653
# 11   75-150  WHCGBM_0000000011        8555
# 12  300-600  WHCGBM_0000000006        6821
# 13  200-400  WHCGBM_0000000006        6817
# 14  150-300  WHCGBM_0000000006        6791
# 15   75-150  WHCGBM_0000000006        6673
# 16  300-600  WHCGBM_0000000013        9396
# 17  200-400  WHCGBM_0000000013        9391
# 18  150-300  WHCGBM_0000000013        9388
# 19   75-150  WHCGBM_0000000013        9363
#
#                       Var missing compared to 300-600
# 0                                                 NaN
# 1                2 intergenic_region 3 intron_variant
# 2    1 downstream_gene_variant 10 intergenic_regio...
# 3    1 downstream_gene_variant 22 intergenic_regio...
# 4                                                 NaN
# 5    1 3_prime_UTR_variant 5 downstream_gene_varia...
# 6    1 3_prime_UTR_variant 10 downstream_gene_vari...
# 7    3 3_prime_UTR_variant 1 5_prime_UTR_variant 2...
# 8                                                 NaN
# 9    1 3_prime_UTR_variant 7 intergenic_region 4 i...
# 10   1 3_prime_UTR_variant 4 downstream_gene_varia...
# 11   2 3_prime_UTR_variant 5 downstream_gene_varia...
# 12                                                NaN
# 13   1 downstream_gene_variant 9 intergenic_region...
# 14   2 downstream_gene_variant 21 intergenic_regio...
# 15   1 3_prime_UTR_variant 6 downstream_gene_varia...
# 16                                                NaN
# 17   1 downstream_gene_variant 4 intergenic_region...
# 18               7 intergenic_region 3 intron_variant
# 19   2 downstream_gene_variant 16 intergenic_regio...

# %%
plt.figure(figsize=(12,7))
varplot = sns.stripplot(x="Sample", y="Num of var", hue="Padding",
                   data=consensusvcfcalls, palette="pastel", size=10, dodge=True)
varplot.set_xticklabels(varplot.get_xticklabels(),rotation=25)
varplot.axes.set_title("Variant numbers lancet based on window and padding size\n",fontsize=20)
plt.savefig('results/var_comparison.png')
