# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
vcfcalls = pd.read_csv("results/all_samples_with_var_comparison", header=None, sep="\t", 
                       names=["Padding", "Sample", "Num of var", "Var missing compared to 300-600"])

# %%
vcfcalls
# Out:
#     Padding             Sample  Num of var  \
# 0   300-600  WHCGBM_0000000011        1383
# 1   200-400  WHCGBM_0000000011        1351
# 2   150-300  WHCGBM_0000000011        1171
# 3    75-150  WHCGBM_0000000011           3
# 4   300-600  WHCGBM_0000000010        1966
# 5   200-400  WHCGBM_0000000010        1851
# 6   150-300  WHCGBM_0000000010        1604
# 7    75-150  WHCGBM_0000000010           1
# 8   300-600  WHCGBM_0000000004         371
# 9   200-400  WHCGBM_0000000004         366
# 10  150-300  WHCGBM_0000000004         310
# 11   75-150  WHCGBM_0000000004           0
# 12  300-600  WHCGBM_0000000006        1013
# 13  200-400  WHCGBM_0000000006         982
# 14  150-300  WHCGBM_0000000006         846
# 15   75-150  WHCGBM_0000000006           0
# 16  300-600  WHCGBM_0000000013         494
# 17  200-400  WHCGBM_0000000013         448
# 18  150-300  WHCGBM_0000000013         358
# 19   75-150  WHCGBM_0000000013           1
#
#                       Var missing compared to 300-600
# 0                                                 NaN
# 1    4 3_prime_UTR_variant 13 downstream_gene_vari...
# 2    4 3_prime_UTR_variant 1 disruptive_inframe_in...
# 3    11 3_prime_UTR_variant 1 5_prime_UTR_prematur...
# 4                                                 NaN
# 5    4 3_prime_UTR_variant 1 5_prime_UTR_variant 1...
# 6    6 3_prime_UTR_variant 1 5_prime_UTR_variant 3...
# 7    20 3_prime_UTR_variant 5 5_prime_UTR_variant ...
# 8                                                 NaN
# 9    1 3_prime_UTR_variant 1 conservative_inframe_...
# 10   2 3_prime_UTR_variant 1 conservative_inframe_...
# 11   4 3_prime_UTR_variant 1 conservative_inframe_...
# 12                                                NaN
# 13   1 5_prime_UTR_variant 3 downstream_gene_varia...
# 14   1 5_prime_UTR_variant 16 downstream_gene_vari...
# 15   2 3_prime_UTR_variant 2 5_prime_UTR_variant 1...
# 16                                                NaN
# 17   2 3_prime_UTR_variant 16 downstream_gene_vari...
# 18   3 3_prime_UTR_variant 21 downstream_gene_vari...
# 19   10 3_prime_UTR_variant 2 5_prime_UTR_variant ...

# %%
plt.figure(figsize=(12,7))
varplot = sns.stripplot(x="Sample", y="Num of var", hue="Padding",
                   data=vcfcalls, palette="pastel", size=10, dodge=True)
varplot.set_xticklabels(varplot.get_xticklabels(),rotation=25)
plt.savefig('results/var_comparison.png')
